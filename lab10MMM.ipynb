# %% [markdown]
# # Лабораторная работа №10

# %% [markdown]
# # 1. Содержательная постановка задачи
# В данной задаче рассматривается модель противоборства между двумя
# регулярными армиями. Исследуется динамика численностей противоборствующих
# сторон. Главной характеристикой соперников в рассматриваемых моделях являются
# численности сторон $ N1(t)≥0 $  и$ N2(t)≥0$.

# %% [markdown]
# # 2. Концептуальная постановка задачи
#
# В данной модели общее количество вооружений у каждой страны изменяется со
# временем в зависимости от трех факторов:
#
#
# 1. Скоростью уменьшения состава из-за причин, непосредственно не связанных с боевыми действиями (болезни, травмы, дезертирство);
# 2. Темпом потерь, обусловленных боевыми действиями противоборствующей стороны (которые в свою очередь определяются качеством ее стратегии и тактики, уровнем морального духа и профессионализмом бойцов, вооружениями и т. д.);
# 3. Скоростью поступления подкреплений, которая считается некоторой заданной функцией времени.

# %% [markdown]
# # 3. Математическая постановка задачи
# Боевые действия между регулярными частями:
#
#
# При этих предположениях для $  N1(t), N2(t)$  получаем систему уравнений
#
#
# $\frac{dN_1}{dt} = -\alpha_1(t)*N_1 - \beta_2*N_2 + \gamma_1(t)$
#
# $\frac{dN_2}{dt} = -\alpha_2(t)*N_2 - \beta_1*N_1 + \gamma_2(t)$
#
# из которой при заданных функциях$ αi, βi, γi, i = 1,2,$ и начальных значениях $N_1(0), N_2(0)$ однозначно определяется решение в любой момент времени $t>0$. Коэффициенты $α1,2(t)≥0$ характеризуют скорости потерь в силу обычных (не боевых) причин,$ β1,2(t)≥0$  – темпы потерь из-за действий соперника,$ γ1,2(t)≥0$  – скорости поступления подкреплений.
#
# #### Боевые действия между регулярными и партизанскими частями:
# Главное отличие в том, что нерегулярные соединения в сравнении с армейскими менее уязвимы, так как действуют скрытно, зачастую оставаясь невидимыми для соперника, вынужденного действовать неизбирательно, по площадям, занимаемым партизанами. Поэтому считается, что темп потерь партизан, проводящих свои операции в разных местах на некоторой известной территории, пропорционален не только численности армейских соединений $N_1(t)$, но и численности самих партизан$ N_2(t)$, т. е. определяется членом вида $β1(t)*N1*N2$. В результате модель становится нелинейной:
# $\frac{dN_1}{dt} = -\alpha_1(t)*N_1 - \beta_2*N_2 + \gamma_1(t)$
#
# $\frac{dN_2}{dt} = -\alpha_2(t)*N_2 - \beta_1*N_1 + \gamma_2(t)$
#
#
# Изучим модели (модели Манчестера) в частном случае: $γ1 = γ2 = 0$ (стороны не получают подкреплений и как бы предоставлены самим себе); $α1 = const, α2 = const, β1 = const, β2 =const$ (последнее означает, в частности, что у противников всегда найдется достаточное количество вооружений, которое может использоваться годными к несению службы бойцами).
#
# Первая модель становится автономной и принимает вид:
#
#
# $\frac{dN_1}{dt} = -\alpha_1(t)*N_1 - \beta_2*N_2 $
#
# $\frac{dN_2}{dt} = -\alpha_2(t)*N_2 - \beta_1*N_1 $
#
#
# Из этих уравнений видно, что в данном случае численности сторон с течением времени могут только убывать. Каков временной характер этого процесса и какая сторона потерпит поражение? Чтобы выяснить этот вопрос, введем еще одно упрощение (вполне оправданное для краткосрочных кампаний): положим $α1 = α2 = 0 $ Другими словами, потери сторон определяются лишь действиями противника. Система упрощается:
#
#
# $\frac{dN_1}{dt} =  - \beta_2*N_2 $
#
# $\frac{dN_2}{dt} =  - \beta_1*N_1 $
#
#
# и легко находится ее интеграл
#
#
# $ \beta_1*N^2_1 - \beta_2*N^2_2 = \beta_1*N_1(0)^2 - \beta_2(0)^2 = C$
#
#
# Из полученного выражения однозначно определяется победитель. При$ С > 0 $побеждает первая армия, при $С < 0$ – вторая, в случае С = 0 стороны уничтожают друг друга одновременно, и победителя нет.
#
#
# Рассмотрим теперь действия регулярной армии против партизан в тех же упрощающих предположениях, что и в предыдущем случае. Модель приобретает вид
#
#
# $\frac{dN_1}{dt} =  - \beta_2*N_2 $
#
# $\frac{dN_2}{dt} =  - \beta_1*N_1*N_2 $
#
#
# Численности сторон, как и прежде, убывают со временем, но по другому закону. Умножим первое уравнение на $β_1*N_1$, второе — на $β_2$ и вычтем второе получившееся уравнение из первого. В итоге придем к уравнению
#
#
# $\frac{d}{dt} [\frac{\beta_1}{2}*N^2_1 - \beta_2*N_2] = 0$
#
#
# Интеграл которого:
#
#
# $ \frac{\beta_1}{2}*N^2_1 - \beta_2*N_2 = \frac{\beta_1}{2}*N^2_1(0) - \beta_2*N_2(0) = C$
#
#
# видно, что при $C > 0$ побеждает армия, при $C < 0$ —партизаны, а при $ C = 0 $ победителя нет.Так же, как и при действии регулярных частей, победа обеспечивается не только начальной численностью, но и боевой выучкой и качеством оружия.

# %% [markdown]
# # Реализация

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
def differ1(y, t):
    b1 = 0.7
    b2 = 0.3
    dydt = [-b2*y[1], -b1*y[0]]
    return dydt

time = np.linspace(0, 30, 1000)
N10 = 4
N20 = 9

plt.figure()

for i in range(11):
    initial_conditions = [N10 + 0.5*i, N20 - 0.5*i]
    Y = odeint(differ1, initial_conditions, time)
    N1 = Y[:, 0]
    N2 = Y[:, 1]
    plt.plot(N1, N2, 'r')

initial_conditions = [5, 7.6376]
Y = odeint(differ1, initial_conditions, time)
N1 = Y[:, 0]
N2 = Y[:, 1]
plt.plot(N1, N2, 'r')

plt.grid()
plt.xlabel('N_1')
plt.ylabel('N_2')
plt.axis([0, 10, 0, 10])
plt.show()

# %% [markdown]
# $N_1$ - Численность первой армии
#
#
# $N_2$ - Численность второй армии
#
# Так как$  β1> β2$ , то есть 1ая армия более профессиональная и с лучшим
# вооружением, то и потери ее будут меньше. Это видно из графика.

# %%
def differ3(y, t):
    a1 = 0.91 * (np.sin(t))**2
    a2 = 0.15
    b1 = 0.7
    b2 = 0.3
    g1 = 0.4 * (np.exp(-0.05 * t))**2
    g2 = 3.9 * (np.sin(t))**2 * (np.cos(t))**2
    yp = [-a1*y[0] - b2*y[1] + g1, -a2*y[1] - b1*y[0] + g2]
    return yp

time = np.linspace(0, 30, 1000)
N10 = 4
N20 = 9

plt.figure()

for i in range(11):
    initial_conditions = [N10 + 0.5*i, N20 - 0.5*i]
    Y = odeint(differ3, initial_conditions, time)
    N1 = Y[:, 0]
    N2 = Y[:, 1]
    plt.plot(N1, N2, 'r')

initial_conditions = [6.2, 6.66]
Y = odeint(differ3, initial_conditions, time)
N1 = Y[:, 0]
N2 = Y[:, 1]
plt.plot(N1, N2, 'r')

plt.grid()
plt.xlabel('N_1')
plt.ylabel('N_2')
plt.axis([0, 10, 0, 10])
plt.show()

# %% [markdown]
# $N_1$ - Численность первой армии
#
#
# $N_2$ - Численность второй армии
#
#
# В местах явного смещения графика видно влияние подкреплений на ситуацию боя.

# %% [markdown]
# ## Вывод :
# Для победы важна не только численность сторон в начале боевых действий N1(0), N2(0), но и их выучка, качество их вооружений, скорость подкреплений и т.д. (т. е. коэффициенты α1, α2, β1, β2).
